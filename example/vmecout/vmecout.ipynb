# %%
import matplotlib
matplotlib.rcParams['text.usetex'] = True

from tfpy.vmec import VMECOut

# %%
case_name = "QAS"
vmec_file = "../datas/VMECDatas/wout_"+case_name+".nc" 
vmeclib = VMECOut(vmec_file)

vmeclib.plotCrossSection(nSurf=7)
